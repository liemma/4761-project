# %%
#pip install "abc_atlas_access[notebooks] @ git+https://github.com/alleninstitute/abc_atlas_access.git"

# %%
from pathlib import Path
from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache
from abc_atlas_access.abc_atlas_cache.anndata_utils import get_gene_data

# %%
download_base = Path('../data/abc_atlas')
abc_cache = AbcProjectCache.from_cache_dir(download_base)

abc_cache.current_manifest

abc_cache.list_manifest_file_names
# Out:
# ['releases/20230630/manifest.json',
#  'releases/20230830/manifest.json',
#  'releases/20231215/manifest.json',
#  'releases/20240330/manifest.json',
#  'releases/20240831/manifest.json',
#  'releases/20241115/manifest.json',
#  'releases/20241130/manifest.json',
#  'releases/20250131/manifest.json',
#  'releases/20250331/manifest.json',
#  'releases/20250531/manifest.json',
#  'releases/20250930/manifest.json',
#  'releases/20251031/manifest.json',
#  'releases/20260131/manifest.json',
#  'releases/20260228/manifest.json',
#  'releases/20260331/manifest.json',
#  'releases/20260415/manifest.json']

# %%
# the latest manifest
abc_cache.load_latest_manifest()
print("after latest manifest loaded:", abc_cache.current_manifest)
# Out:
# after latest manifest loaded: releases/20260415/manifest.json

# %%
abc_cache.list_directories
# Out:
# ['ASAP-PMDBS-10X',
#  'ASAP-PMDBS-taxonomy',
#  'Allen-CCF-2020',
#  'Consensus-WMB-AIBS-10X',
#  'Consensus-WMB-Macosko-10X',
#  'Consensus-WMB-integrated-taxonomy',
#  'Developing-Mouse-Vis-Cortex-10X',
#  'Developing-Mouse-Vis-Cortex-taxonomy',
#  'HMBA-10xMultiome-BG',
#  'HMBA-10xMultiome-BG-Aligned',
#  'HMBA-BG-taxonomy-CCN20250428',
#  'HMBA-MERSCOPE-H22.30.001-BG',
#  'HMBA-MERSCOPE-QM23.50.001-BG',
#  'HMBA-Macaque-PatchSeq',
#  'HMBA-Xenium-CJ23.56.004-BG',
#  'MERFISH-C57BL6J-638850',
#  'MERFISH-C57BL6J-638850-CCF',
#  'MERFISH-C57BL6J-638850-imputed',
#  'MERFISH-C57BL6J-638850-sections',
#  'SEAAD-taxonomy',
#  'WHB-10Xv3',
#  'WHB-taxonomy',
#  'WMB-10X',
#  'WMB-10XMulti',
#  'WMB-10Xv2',
#  'WMB-10Xv3',
#  'WMB-neighborhoods',
#  'WMB-taxonomy',
#  'Zeng-Aging-Mouse-10Xv3',
#  'Zeng-Aging-Mouse-WMB-taxonomy',
#  'Zhuang-ABCA-1',
#  'Zhuang-ABCA-1-CCF',
#  'Zhuang-ABCA-2',
#  'Zhuang-ABCA-2-CCF',
#  'Zhuang-ABCA-3',
#  'Zhuang-ABCA-3-CCF',
#  'Zhuang-ABCA-4',
#  'Zhuang-ABCA-4-CCF',
#  'mmc-gene-mapper']

# %%
#metadata of the original dataset
merfish_metadata = abc_cache.get_metadata_deferred(
    dataset_label='Zhuang-ABCA-1', 
    file_name='cell_metadata'
).read()

#CCF aligned metadata of the same dataset
ccf_metadata = cache.get_metadata_deferred(
    dataset_label='Zhuang-ABCA-1-CCF', 
    file_name='cell_metadata'
).read()

#Add the subregion information from the CCF aligned metadata to the original metadata
merfish_metadata['subregion'] = ccf_metadata['parcellation_substructure_label']

# Count cells in each section_label (slice) and sort by slice label
slice_counts = merfish_metadata['section_label'].value_counts().sort_index()
print("Slices(top 20):")
print(slice_counts.head(20))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 #metadata of the original dataset
# ----> 2 merfish_metadata = abc_cache.get_metadata_deferred(
#       3     dataset_label='Zhuang-ABCA-1',
#       4     file_name='cell_metadata'
#       5 ).read()
#       7 #CCF aligned metadata of the same dataset
#       8 ccf_metadata = cache.get_metadata_deferred(
#       9     dataset_label='Zhuang-ABCA-1-CCF',
#      10     file_name='cell_metadata'
#      11 ).read()
#
# AttributeError: 'AbcProjectCache' object has no attribute 'get_metadata_deferred'
